# %% [markdown]
# Importing the required packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn import metrics
from sklearn.metrics import mean_absolute_percentage_error as mape
from sklearn.metrics import explained_variance_score,r2_score
from time import time
from sklearn.linear_model import LinearRegression, Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score
from datetime import datetime, date
import calendar
import holidays
from sklearn.model_selection import GridSearchCV
  
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading the dataset into a python dataframe

# %%
df = pd.read_csv('train.csv')
display(df.head())
display(df.tail())
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10
#               date  store  item  sales
# 912995  2017-12-27     10    50     63
# 912996  2017-12-28     10    50     59
# 912997  2017-12-29     10    50     74
# 912998  2017-12-30     10    50     62
# 912999  2017-12-31     10    50     82

# %% [markdown]
# #### Dataset Exploration

# %%
df.shape
# Out:
# (913000, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 913000 entries, 0 to 912999
#
# Data columns (total 4 columns):
#
#  #   Column  Non-Null Count   Dtype
#
# ---  ------  --------------   -----
#
#  0   date    913000 non-null  object
#
#  1   store   913000 non-null  int64
#
#  2   item    913000 non-null  int64
#
#  3   sales   913000 non-null  int64
#
# dtypes: int64(3), object(1)
#
# memory usage: 27.9+ MB

# %%
df.describe()
# Out:
#                store           item          sales
# count  913000.000000  913000.000000  913000.000000
# mean        5.500000      25.500000      52.250287
# std         2.872283      14.430878      28.801144
# min         1.000000       1.000000       0.000000
# 25%         3.000000      13.000000      30.000000
# 50%         5.500000      25.500000      47.000000
# 75%         8.000000      38.000000      70.000000
# max        10.000000      50.000000     231.000000

# %% [markdown]
# Split the data into Train and Test - The dataset is split in such a way that the training dataset contains data from the year 2013 to 2016. WHile, the testing dataset contains data for the year 2017

# %%
parts = df["date"].str.split("-", n = 3, expand = True)
df["year"]= parts[0].astype('int')

train = df[(df["year"] != 2017) & (df["store"] == 1) & (df["item"] == 1)]

test = df[(df["year"] == 2017) & (df["store"] == 1) & (df["item"] == 1)]

# %%
print(train)
print(test)
# Out:
#             date  store  item  sales  year
#
# 0     2013-01-01      1     1     13  2013
#
# 1     2013-01-02      1     1     11  2013
#
# 2     2013-01-03      1     1     14  2013
#
# 3     2013-01-04      1     1     13  2013
#
# 4     2013-01-05      1     1     10  2013
#
# ...          ...    ...   ...    ...   ...
#
# 1456  2016-12-27      1     1     10  2016
#
# 1457  2016-12-28      1     1     16  2016
#
# 1458  2016-12-29      1     1     21  2016
#
# 1459  2016-12-30      1     1     24  2016
#
# 1460  2016-12-31      1     1     14  2016
#
#
#
# [1461 rows x 5 columns]
#
#             date  store  item  sales  year
#
# 1461  2017-01-01      1     1     19  2017
#
# 1462  2017-01-02      1     1     15  2017
#
# 1463  2017-01-03      1     1     10  2017
#
# 1464  2017-01-04      1     1     16  2017
#
# 1465  2017-01-05      1     1     14  2017
#
# ...          ...    ...   ...    ...   ...
#
# 1821  2017-12-27      1     1     14  2017
#
# 1822  2017-12-28      1     1     19  2017
#
# 1823  2017-12-29      1     1     15  2017
#
# 1824  2017-12-30      1     1     27  2017
#
# 1825  2017-12-31      1     1     23  2017
#
#
#
# [365 rows x 5 columns]

# %% [markdown]
# #### Setting up a benchmark (Before preprocessing the data)

# %% [markdown]
# Benchmark 1 - The approach followed in this is a very naive forcasting method where we are just taking an average of that particular day for each year and then predicting the value of the next year same day as that average value.
# For Example:
# Predicted inventory requirement value for Jan 1st 2017 would be Average value of Jan 1st Sales value of the years (2013, 2014, 2015 and 2016)

# %%
train["month_day"] = train.date.map(lambda x:str(x)[5:12])

# %%
train = train[train["month_day"] != '02-29']

# %%
X_Pred = train.groupby("month_day").sales.mean().to_frame()

# %%
X_Test = test[["sales"]]

# %% [markdown]
# Benchmark 1 - MAPE value to determine accuracy of the model

# %%
mape(X_Pred, X_Test)
# Out:
# 0.3029780598276817

# %% [markdown]
# #### Feature Engineering

# %% [markdown]
# To get better results first try to introduce a few other attributes which might help the model predict better. To do so we perform Feature Engineering

# %%
#Splitting the Date coumn into Year, Month and Day respectively
parts = df["date"].str.split("-", n = 3, expand = True)
df["year"]= parts[0].astype('int')
df["month"]= parts[1].astype('int')
df["day"]= parts[2].astype('int')
df.head()
# Out:
#          date  store  item  sales  year  month  day
# 0  2013-01-01      1     1     13  2013      1    1
# 1  2013-01-02      1     1     11  2013      1    2
# 2  2013-01-03      1     1     14  2013      1    3
# 3  2013-01-04      1     1     13  2013      1    4
# 4  2013-01-05      1     1     10  2013      1    5

# %%
#Adding weekend column
def weekend_or_weekday(year,month,day):
      
    d = datetime(year,month,day)
    if d.weekday()>4:
        return 1
    else:
        return 0
  
df['weekend'] = df.apply(lambda x:weekend_or_weekday(x['year'], x['month'], x['day']), axis=1)
df.head()
# Out:
#          date  store  item  sales  year  month  day  weekend
# 0  2013-01-01      1     1     13  2013      1    1        0
# 1  2013-01-02      1     1     11  2013      1    2        0
# 2  2013-01-03      1     1     14  2013      1    3        0
# 3  2013-01-04      1     1     13  2013      1    4        0
# 4  2013-01-05      1     1     10  2013      1    5        1

# %%
#Adding holdiays in a separate columnn - For India
def is_holiday(x):
    
  india_holidays = holidays.country_holidays('IN')
  
  if india_holidays.get(x):
    return 1
  else:
    return 0
  
df['holidays'] = df['date'].apply(is_holiday)
df.head()
# Out:
#          date  store  item  sales  year  month  day  weekend  holidays
# 0  2013-01-01      1     1     13  2013      1    1        0         0
# 1  2013-01-02      1     1     11  2013      1    2        0         0
# 2  2013-01-03      1     1     14  2013      1    3        0         0
# 3  2013-01-04      1     1     13  2013      1    4        0         0
# 4  2013-01-05      1     1     10  2013      1    5        1         0

# %%
#Adding columns to capture cyclic nature of the data (if any)
df['m1'] = np.sin(df['month'] * (2 * np.pi / 12))
df['m2'] = np.cos(df['month'] * (2 * np.pi / 12))
df.head()
# Out:
#          date  store  item  sales  year  month  day  weekend  holidays   m1  \
# 0  2013-01-01      1     1     13  2013      1    1        0         0  0.5
# 1  2013-01-02      1     1     11  2013      1    2        0         0  0.5
# 2  2013-01-03      1     1     14  2013      1    3        0         0  0.5
# 3  2013-01-04      1     1     13  2013      1    4        0         0  0.5
# 4  2013-01-05      1     1     10  2013      1    5        1         0  0.5
#
#          m2
# 0  0.866025
# 1  0.866025
# 2  0.866025
# 3  0.866025
# 4  0.866025

# %%
#Adding column to identify the day of the week
def which_day(year, month, day):
      
    d = datetime(year,month,day)
    return d.weekday()
  
df['weekday'] = df.apply(lambda x: which_day(x['year'],
                                                      x['month'],
                                                      x['day']),
                                   axis=1)
df.head()
# Out:
#          date  store  item  sales  year  month  day  weekend  holidays   m1  \
# 0  2013-01-01      1     1     13  2013      1    1        0         0  0.5
# 1  2013-01-02      1     1     11  2013      1    2        0         0  0.5
# 2  2013-01-03      1     1     14  2013      1    3        0         0  0.5
# 3  2013-01-04      1     1     13  2013      1    4        0         0  0.5
# 4  2013-01-05      1     1     10  2013      1    5        1         0  0.5
#
#          m2  weekday
# 0  0.866025        1
# 1  0.866025        2
# 2  0.866025        3
# 3  0.866025        4
# 4  0.866025        5

# %%
df.drop('date', axis=1, inplace=True)

# %% [markdown]
# #### Exploratory Data Analysis

# %%
df['store'].nunique(), df['item'].nunique()
# Out:
# (10, 50)

# %% [markdown]
# From here we can conclude that there are 10 unique stores and they sell 50 different products

# %%
plt.subplots(figsize=(12, 5))
plt.subplot(1, 2, 1)
sb.distplot(df['sales'])

plt.subplot(1, 2, 2)
sb.boxplot(df['sales'])
plt.show()

# %% [markdown]
# As per the above graph we can conclude that the values above unit sales > 140 are the outliers. In our analysis we remove them as we want a clean prediction and these values should not skew the results

# %%
df = df[df['sales']<140]

# %% [markdown]
# #### Benchmark 2: Setting up this benchmark after preprocessing the data

# %% [markdown]
# Splitting the dataset into training and testing after preprocessing

# %%
train = df[(df["year"] != 2017) & (df["store"] == 1) & (df["item"] == 1)]

test = df[(df["year"] == 2017) & (df["store"] == 1) & (df["item"] == 1)]

X_train = train.drop(['sales', 'year'], axis=1)

X_test = test.drop(['sales', 'year'], axis=1)

y_train = train['sales'].values

y_test = test['sales'].values

X_train.shape, X_test.shape
# Out:
# ((1461, 9), (365, 9))

# %%
X_train
# Out:
# array([[ 0.        ,  0.        , -1.6014511 , ...,  0.71523725,
#          1.22531488, -1.00085668],
#        [ 0.        ,  0.        , -1.6014511 , ...,  0.71523725,
#          1.22531488, -0.50042834],
#        [ 0.        ,  0.        , -1.6014511 , ...,  0.71523725,
#          1.22531488,  0.        ],
#        ...,
#        [ 0.        ,  0.        ,  1.58815364, ...,  0.00677945,
#          1.41442871,  0.        ],
#        [ 0.        ,  0.        ,  1.58815364, ...,  0.00677945,
#          1.41442871,  0.50042834],
#        [ 0.        ,  0.        ,  1.58815364, ...,  0.00677945,
#          1.41442871,  1.00085668]])

# %%
# Standardization the features for stable and fast training.
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Training the dataset on different models to check the results and use the best one for prediction

# %%
regressors = [
    KNeighborsRegressor(),
    GradientBoostingRegressor(),
    ExtraTreesRegressor(),
    RandomForestRegressor(),
    DecisionTreeRegressor(),
    LinearRegression(),
    XGBRegressor(),
    Lasso(),
    Ridge()
]

# %%
head = 10
for model in regressors[:head]:
    start = time()
    model.fit(X_train, y_train)
    train_time = time() - start
    start = time()
    y_pred = model.predict(X_test)
    predict_time = time()-start    
    print(model)
    print("\tTraining time: %0.3fs" % train_time)
    print("\tPrediction time: %0.3fs" % predict_time)
    print("\tExplained variance:", explained_variance_score(y_test, y_pred))
    print("\tMean absolute percentage error:", mape(y_test, y_pred))
    print("\tR2 score:", r2_score(y_test, y_pred))
    print()
# Out:
# KNeighborsRegressor()
#
# 	Training time: 0.001s
#
# 	Prediction time: 0.004s
#
# 	Explained variance: 0.4422094407339521
#
# 	Mean absolute percentage error: 0.21249268163476737
#
# 	R2 score: 0.29245233848201135
#
#
#
# GradientBoostingRegressor()
#
# 	Training time: 0.096s
#
# 	Prediction time: 0.001s
#
# 	Explained variance: 0.5164797814350244
#
# 	Mean absolute percentage error: 0.19893805382451837
#
# 	R2 score: 0.360547994398143
#
#
#
# ExtraTreesRegressor()
#
# 	Training time: 0.524s
#
# 	Prediction time: 0.022s
#
# 	Explained variance: 0.2885607457890814
#
# 	Mean absolute percentage error: 0.24389875253266693
#
# 	R2 score: 0.1738299166394145
#
#
#
# RandomForestRegressor()
#
# 	Training time: 0.715s
#
# 	Prediction time: 0.033s
#
# 	Explained variance: 0.4207003350807642
#
# 	Mean absolute percentage error: 0.22004424322764518
#
# 	R2 score: 0.301416920395434
#
#
#
# DecisionTreeRegressor()
#
# 	Training time: 0.008s
#
# 	Prediction time: 0.000s
#
# 	Explained variance: 0.00940916250669821
#
# 	Mean absolute percentage error: 0.2816230734470529
#
# 	R2 score: -0.07769315481870853
#
#
#
# LinearRegression()
#
# 	Training time: 0.034s
#
# 	Prediction time: 0.000s
#
# 	Explained variance: 0.5126013818855181
#
# 	Mean absolute percentage error: 0.19596474799221467
#
# 	R2 score: 0.35565613536127627
#
#
#
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#
#              early_stopping_rounds=None, enable_categorical=False,
#
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#
#              grow_policy='depthwise', importance_type=None,
#
#              interaction_constraints='', learning_rate=0.300000012, max_bin=256,
#
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#
#              max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#
#              monotone_constraints='()', n_estimators=100, n_jobs=0,
#
#              num_parallel_tree=1, predictor='auto', random_state=0, ...)
#
# 	Training time: 0.230s
#
# 	Prediction time: 0.006s
#
# 	Explained variance: 0.3362681889557346
#
# 	Mean absolute percentage error: 0.23417005234774682
#
# 	R2 score: 0.20746463012026362
#
#
#
# Lasso()
#
# 	Training time: 0.004s
#
# 	Prediction time: 0.000s
#
# 	Explained variance: 0.39269818817920643
#
# 	Mean absolute percentage error: 0.21780948119437735
#
# 	R2 score: 0.2350598591318409
#
#
#
# Ridge()
#
# 	Training time: 0.008s
#
# 	Prediction time: 0.000s
#
# 	Explained variance: 0.5125371349120778
#
# 	Mean absolute percentage error: 0.19597370521368448
#
# 	R2 score: 0.3555914753985442

# %% [markdown]
# From the above results, we can see that Gradient Boosting performed the best among all the models. Hence we set that as the second benchmark. Now lets see if we can improve its accuracy.

# %%
parameters = { 'loss' : ['ls', 'lad', 'huber', 'quantile'],
              'learning_rate' : (0.05,0.25,0.50,1),
              'criterion' : ['friedman_mse', 'mse', 'mae'],
              'max_features' : ['auto', 'sqrt', 'log2']
             }

# %%
grid = GridSearchCV(GradientBoostingRegressor(),parameters)
model = grid.fit(X_train,y_train)
print(model.best_params_,'\n')
print(model.best_estimator_,'\n')
# Out:
# {'criterion': 'friedman_mse', 'learning_rate': 0.05, 'loss': 'ls', 'max_features': 'sqrt'}
#
#
#
# GradientBoostingRegressor(learning_rate=0.05, loss='ls', max_features='sqrt')

# %%
start = time()
model = GradientBoostingRegressor(learning_rate = 0.05, loss = 'ls', max_features = 'sqrt')
model.fit(X_train, y_train)
train_time = time() - start
start = time()
y_pred = model.predict(X_test)
predict_time = time()-start    
print(model)
print("\tTraining time: %0.3fs" % train_time)
print("\tPrediction time: %0.3fs" % predict_time)
print("\tExplained variance:", explained_variance_score(y_test, y_pred))
print("\tMean absolute percentage error:", mape(y_test, y_pred))
print("\tR2 score:", r2_score(y_test, y_pred))
# Out:
# GradientBoostingRegressor(learning_rate=0.05, loss='ls', max_features='sqrt')
#
# 	Training time: 0.040s
#
# 	Prediction time: 0.002s
#
# 	Explained variance: 0.5175109789677637
#
# 	Mean absolute percentage error: 0.19748075802444168
#
# 	R2 score: 0.36112044652639663

# %%
all_models = {}

for alpha in [0.05, 0.5, 0.95]:
    gbr = GradientBoostingRegressor(learning_rate = 0.05, loss = 'ls', max_features = 'sqrt', alpha=alpha)
    all_models["q %1.2f" % alpha] = gbr.fit(X_train, y_train)

all_models["mse"] = gbr.fit(X_train, y_train)

# %%
y_pred = all_models["mse"].predict(X_test)
y_lower = all_models["q 0.05"].predict(X_test)
y_upper = all_models["q 0.95"].predict(X_test)
y_med = all_models["q 0.50"].predict(X_test)

# %%
mape(y_test, y_lower)
# Out:
# 0.19770327047143124

# %% [markdown]
# This is the final version of the model, after hyperparameter optimization. Which will be used to predict the 2018 inventory (first 3 months)

# %% [markdown]
# #### Predicting the inventory requirement for the year 2018 (First 3 months)

# %%
Pred = pd.read_csv('test.csv')
display(Pred.head())
display(Pred.tail())
Pred.shape
# Out:
#    id        date  store  item
# 0   0  2018-01-01      1     1
# 1   1  2018-01-02      1     1
# 2   2  2018-01-03      1     1
# 3   3  2018-01-04      1     1
# 4   4  2018-01-05      1     1
#           id        date  store  item
# 44995  44995  2018-03-27     10    50
# 44996  44996  2018-03-28     10    50
# 44997  44997  2018-03-29     10    50
# 44998  44998  2018-03-30     10    50
# 44999  44999  2018-03-31     10    50
# (45000, 4)

# %%
Pred = Pred[(Pred["store"] == 1) & (Pred["item"] == 1)]
Pred.shape
# Out:
# (90, 4)

# %%
parts = Pred["date"].str.split("-", n = 3, expand = True)
Pred["year"]= parts[0].astype('int')
Pred["month"]= parts[1].astype('int')
Pred["day"]= parts[2].astype('int')
Pred.head()
# Out:
#    id        date  store  item  year  month  day
# 0   0  2018-01-01      1     1  2018      1    1
# 1   1  2018-01-02      1     1  2018      1    2
# 2   2  2018-01-03      1     1  2018      1    3
# 3   3  2018-01-04      1     1  2018      1    4
# 4   4  2018-01-05      1     1  2018      1    5

# %%
Pred['weekend'] = Pred.apply(lambda x:weekend_or_weekday(x['year'], x['month'], x['day']), axis=1)
Pred.head()
# Out:
#    id        date  store  item  year  month  day  weekend
# 0   0  2018-01-01      1     1  2018      1    1        0
# 1   1  2018-01-02      1     1  2018      1    2        0
# 2   2  2018-01-03      1     1  2018      1    3        0
# 3   3  2018-01-04      1     1  2018      1    4        0
# 4   4  2018-01-05      1     1  2018      1    5        0

# %%
Pred['holidays'] = Pred['date'].apply(is_holiday)
Pred.head()
# Out:
#    id        date  store  item  year  month  day  weekend  holidays
# 0   0  2018-01-01      1     1  2018      1    1        0         0
# 1   1  2018-01-02      1     1  2018      1    2        0         0
# 2   2  2018-01-03      1     1  2018      1    3        0         0
# 3   3  2018-01-04      1     1  2018      1    4        0         0
# 4   4  2018-01-05      1     1  2018      1    5        0         0

# %%
Pred['m1'] = np.sin(Pred['month'] * (2 * np.pi / 12))
Pred['m2'] = np.cos(Pred['month'] * (2 * np.pi / 12))
Pred.head()
# Out:
#    id        date  store  item  year  month  day  weekend  holidays   m1  \
# 0   0  2018-01-01      1     1  2018      1    1        0         0  0.5
# 1   1  2018-01-02      1     1  2018      1    2        0         0  0.5
# 2   2  2018-01-03      1     1  2018      1    3        0         0  0.5
# 3   3  2018-01-04      1     1  2018      1    4        0         0  0.5
# 4   4  2018-01-05      1     1  2018      1    5        0         0  0.5
#
#          m2
# 0  0.866025
# 1  0.866025
# 2  0.866025
# 3  0.866025
# 4  0.866025

# %%
Pred['weekday'] = Pred.apply(lambda x: which_day(x['year'],
                                                      x['month'],
                                                      x['day']),
                                   axis=1)

Pred.head()
# Out:
#    id        date  store  item  year  month  day  weekend  holidays   m1  \
# 0   0  2018-01-01      1     1  2018      1    1        0         0  0.5
# 1   1  2018-01-02      1     1  2018      1    2        0         0  0.5
# 2   2  2018-01-03      1     1  2018      1    3        0         0  0.5
# 3   3  2018-01-04      1     1  2018      1    4        0         0  0.5
# 4   4  2018-01-05      1     1  2018      1    5        0         0  0.5
#
#          m2  weekday
# 0  0.866025        0
# 1  0.866025        1
# 2  0.866025        2
# 3  0.866025        3
# 4  0.866025        4

# %%
Pred.drop('date', axis=1, inplace=True)

# %%
Pred
# Out:
#     id  store  item  year  month  day  weekend  holidays   m1            m2  \
# 0    0      1     1  2018      1    1        0         0  0.5  8.660254e-01
# 1    1      1     1  2018      1    2        0         0  0.5  8.660254e-01
# 2    2      1     1  2018      1    3        0         0  0.5  8.660254e-01
# 3    3      1     1  2018      1    4        0         0  0.5  8.660254e-01
# 4    4      1     1  2018      1    5        0         0  0.5  8.660254e-01
# ..  ..    ...   ...   ...    ...  ...      ...       ...  ...           ...
# 85  85      1     1  2018      3   27        0         0  1.0  6.123234e-17
# 86  86      1     1  2018      3   28        0         0  1.0  6.123234e-17
# 87  87      1     1  2018      3   29        0         0  1.0  6.123234e-17
# 88  88      1     1  2018      3   30        0         0  1.0  6.123234e-17
# 89  89      1     1  2018      3   31        1         0  1.0  6.123234e-17
#
#     weekday
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ..      ...
# 85        1
# 86        2
# 87        3
# 88        4
# 89        5
#
# [90 rows x 11 columns]

# %%
Pred.set_index("id", inplace = True)

# %%
Pred
# Out:
#     store  item  year  month  day  weekend  holidays   m1            m2  \
# id
# 0       1     1  2018      1    1        0         0  0.5  8.660254e-01
# 1       1     1  2018      1    2        0         0  0.5  8.660254e-01
# 2       1     1  2018      1    3        0         0  0.5  8.660254e-01
# 3       1     1  2018      1    4        0         0  0.5  8.660254e-01
# 4       1     1  2018      1    5        0         0  0.5  8.660254e-01
# ..    ...   ...   ...    ...  ...      ...       ...  ...           ...
# 85      1     1  2018      3   27        0         0  1.0  6.123234e-17
# 86      1     1  2018      3   28        0         0  1.0  6.123234e-17
# 87      1     1  2018      3   29        0         0  1.0  6.123234e-17
# 88      1     1  2018      3   30        0         0  1.0  6.123234e-17
# 89      1     1  2018      3   31        1         0  1.0  6.123234e-17
#
#     weekday
# id
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ..      ...
# 85        1
# 86        2
# 87        3
# 88        4
# 89        5
#
# [90 rows x 10 columns]

# %%
#Predicting the Inventory for the year 2018, using the trained model

Pred = scaler.fit_transform(Pred)

Pred_Y = model.predict(Pred)
predict_time = time()-start    
print(model)
print("\tTraining time: %0.3fs" % train_time)
print("\tPrediction time: %0.3fs" % predict_time)

print(Pred_X)
print(Pred_Y.size)

# %% [markdown]
# ## Thank You!
